# %% [markdown]
# <a href="https://colab.research.google.com/github/Zuhair0000/Deep_Learning-ANN/blob/main/cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Libraries**

# %%
import tensorflow as tf

# %% [markdown]
# # **Data Mount**

# %%
# !pip install google-cloud

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_dir = '/content/drive/MyDrive/data/training_set'
test_dir = '/content/drive/MyDrive/data/test_set'

# %% [markdown]
# # **Data Preprocessing**

# %%
training_set = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(64, 64),
    batch_size=32,
    label_mode='binary'
)

data_augmentation = tf.keras.Sequential([
    tf.keras.layers.Rescaling(1./255),
    tf.keras.layers.RandomFlip('horizontal'),
    tf.keras.layers.RandomZoom(0.2),
    tf.keras.layers.RandomRotation(0.1)
])
# Out:
# Found 8000 files belonging to 2 classes.

# %%
test_set = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=(64, 64),
    batch_size=32,
    label_mode='binary',
    shuffle=False
)

test_set = test_set.map(
    lambda x, y: (tf.keras.layers.Rescaling(1./255)(x), y)
)
# Out:
# Found 2000 files belonging to 2 classes.

# %% [markdown]
# # **Building CNN**

# %% [markdown]
# Initialising CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# Adding second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# Output layer

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# # **Train CNN**

# %% [markdown]
# Compile

# %%
cnn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Training

# %%
cnn.fit(x=training_set, validation_data=test_set, epochs=25)
# Out:
# Epoch 1/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1078s 4s/step - accuracy: 0.5565 - loss: 6.2678 - val_accuracy: 0.5005 - val_loss: 0.6930
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 162ms/step - accuracy: 0.6325 - loss: 0.6240 - val_accuracy: 0.5000 - val_loss: 0.6943
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 161ms/step - accuracy: 0.6956 - loss: 0.5389 - val_accuracy: 0.5000 - val_loss: 0.6980
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 163ms/step - accuracy: 0.7669 - loss: 0.4507 - val_accuracy: 0.5000 - val_loss: 0.7057
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 160ms/step - accuracy: 0.8156 - loss: 0.3859 - val_accuracy: 0.5000 - val_loss: 0.7082
# Epoch 6/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 40s 161ms/step - accuracy: 0.8403 - loss: 0.3454 - val_accuracy: 0.5000 - val_loss: 0.7130
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 41s 164ms/step - accuracy: 0.8778 - loss: 0.2786 - val_accuracy: 0.5000 - val_loss: 0.7394
# Epoch 8/25
# ...
